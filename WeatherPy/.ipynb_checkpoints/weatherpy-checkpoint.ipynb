# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# URL for weather queries:
weather_query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

# the lists to be used in the dataframe:
city_names = []
countries = []
dates = []
latitudes = []
longitudes = []
max_temps = []
wind_speeds = []
cloudiness = []
humidities = []

# Counting variables for query loop:
record_count = 0
set_count = 1

# Loop that creates dataframe's columns:
for city in cities:
    try:
        response = requests.get(weather_query_url + city.replace(" ", "&")).json()
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        latitudes.append(response['coord']['lat'])
        longitudes.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        humidities.append(response['main']['humidity'])
        wind_speeds.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        # Print log:
        if record_count > 48:
            record_count = 1
            set_count += 1
            city_names.append(city)
        else:
            record_count += 1
            city_names.append(city)
            print(f'Processing Record {record_count} of Set {set_count} | {city}')
    except:
        print('City not found. Skipping...')
print('----------Data Retrieval Complete----------')
# Out:
# Processing Record 1 of Set 1 | dhidhdhoo
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | itarema
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | sterling
# Processing Record 6 of Set 1 | vila franca do campo
# Processing Record 7 of Set 1 | notodden
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 1 | olot
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | huckeswagen
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | guerrero negro
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | orda
# Processing Record 15 of Set 1 | churapcha
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | hami
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 26 of Set 1 | mabaruma
# Processing Record 27 of Set 1 | bintulu
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | taicheng
# Processing Record 30 of Set 1 | sistranda
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | kismayo
# Processing Record 34 of Set 1 | antropovo
# Processing Record 35 of Set 1 | fortuna
# Processing Record 36 of Set 1 | hasaki
# City not found. Skipping...
# Processing Record 37 of Set 1 | nanortalik
# Processing Record 38 of Set 1 | sarai
# City not found. Skipping...
# Processing Record 39 of Set 1 | mahebourg
# City not found. Skipping...
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | pankrushikha
# City not found. Skipping...
# Processing Record 42 of Set 1 | yako
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | madang
# Processing Record 48 of Set 1 | nova odesa
# Processing Record 49 of Set 1 | tura
# Processing Record 2 of Set 2 | ambon
# Processing Record 3 of Set 2 | esperance
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | melito di porto salvo
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | tazmalt
# Processing Record 9 of Set 2 | port hedland
# Processing Record 10 of Set 2 | richards bay
# Processing Record 11 of Set 2 | bonnyville
# Processing Record 12 of Set 2 | yaan
# Processing Record 13 of Set 2 | quelimane
# Processing Record 14 of Set 2 | harlingen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 2 | dingle
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | buraydah
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | altay
# Processing Record 20 of Set 2 | labuhan
# Processing Record 21 of Set 2 | udachnyy
# Processing Record 22 of Set 2 | aleysk
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | atagay
# Processing Record 25 of Set 2 | abnub
# Processing Record 26 of Set 2 | mana
# Processing Record 27 of Set 2 | niquelandia
# Processing Record 28 of Set 2 | port hardy
# Processing Record 29 of Set 2 | orlik
# City not found. Skipping...
# Processing Record 30 of Set 2 | eureka
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | turayf
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | baharampur
# Processing Record 35 of Set 2 | hawalli
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | broome
# Processing Record 38 of Set 2 | port macquarie
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | ruzhyn
# Processing Record 41 of Set 2 | college
# City not found. Skipping...
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 2 | simdega
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | ust-kuyga
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | jijiga
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 2 of Set 3 | mendeleyevo
# Processing Record 3 of Set 3 | coahuayana
# Processing Record 4 of Set 3 | progreso
# Processing Record 5 of Set 3 | baruun-urt
# Processing Record 6 of Set 3 | mys shmidta
# Processing Record 7 of Set 3 | clyde river
# City not found. Skipping...
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | aksu
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | mount isa
# Processing Record 13 of Set 3 | san quintin
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | tabou
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | hambantota
# Processing Record 18 of Set 3 | torbay
# Processing Record 19 of Set 3 | pangnirtung
# Processing Record 20 of Set 3 | fairbanks
# Processing Record 21 of Set 3 | saint-francois
# Processing Record 22 of Set 3 | ponta do sol
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | ossora
# Processing Record 25 of Set 3 | cape town
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 3 | narsaq
# City not found. Skipping...
# Processing Record 27 of Set 3 | lavrentiya
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | alamogordo
# Processing Record 30 of Set 3 | yulara
# Processing Record 31 of Set 3 | qaqortoq
# Processing Record 32 of Set 3 | laurel
# Processing Record 33 of Set 3 | severo-kurilsk
# Processing Record 34 of Set 3 | dzitas
# Processing Record 35 of Set 3 | tomatlan
# Processing Record 36 of Set 3 | geraldton
# City not found. Skipping...
# Processing Record 37 of Set 3 | ancud
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | kazerun
# City not found. Skipping...
# Processing Record 41 of Set 3 | lachi
# City not found. Skipping...
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | akyab
# Processing Record 44 of Set 3 | menongue
# Processing Record 45 of Set 3 | nanga eboko
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | sakaiminato
# Processing Record 48 of Set 3 | taunggyi
# Processing Record 49 of Set 3 | ballina
# Processing Record 2 of Set 4 | maraa
# Processing Record 3 of Set 4 | xiongzhou
# Processing Record 4 of Set 4 | harrisonburg
# City not found. Skipping...
# Processing Record 5 of Set 4 | bengkulu
# City not found. Skipping...
# Processing Record 6 of Set 4 | dolores
# Processing Record 7 of Set 4 | northam
# Processing Record 8 of Set 4 | itupiranga
# Processing Record 9 of Set 4 | karpathos
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | alugan
# Processing Record 13 of Set 4 | foz
# Processing Record 14 of Set 4 | lata
# Processing Record 15 of Set 4 | katobu
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | lebu
# Processing Record 18 of Set 4 | fort nelson
# Processing Record 19 of Set 4 | zhigansk
# City not found. Skipping...
# Processing Record 20 of Set 4 | mandalgovi
# Processing Record 21 of Set 4 | naze
# City not found. Skipping...
# Processing Record 22 of Set 4 | samarai
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | maues
# Processing Record 25 of Set 4 | bure
# Processing Record 26 of Set 4 | butaritari
# Processing Record 27 of Set 4 | katsuura
# Processing Record 28 of Set 4 | tual
# Processing Record 29 of Set 4 | khani
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | anadyr
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | kavieng
# Processing Record 34 of Set 4 | portland
# Processing Record 35 of Set 4 | aden
# Processing Record 36 of Set 4 | winneba
# Processing Record 37 of Set 4 | haines junction
# Processing Record 38 of Set 4 | tasiilaq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | villa carlos paz
# Processing Record 41 of Set 4 | grindavik
# Processing Record 42 of Set 4 | inhambane
# Processing Record 43 of Set 4 | innisfail
# Processing Record 44 of Set 4 | gamba
# Processing Record 45 of Set 4 | sola
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | lagoa
# Processing Record 48 of Set 4 | inta
# Processing Record 49 of Set 4 | assiniboia
# Processing Record 2 of Set 5 | axim
# Processing Record 3 of Set 5 | vanimo
# Processing Record 4 of Set 5 | kondoa
# City not found. Skipping...
# Processing Record 5 of Set 5 | charleville-mezieres
# Processing Record 6 of Set 5 | skibotn
# Processing Record 7 of Set 5 | biak
# Processing Record 8 of Set 5 | atasu
# Processing Record 9 of Set 5 | tessalit
# Processing Record 10 of Set 5 | mbanza-ngungu
# Processing Record 11 of Set 5 | motygino
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | grand river south east
# Processing Record 14 of Set 5 | wanaka
# Processing Record 15 of Set 5 | wewak
# Processing Record 16 of Set 5 | lubango
# Processing Record 17 of Set 5 | douglas
# City not found. Skipping...
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | canton
# Processing Record 21 of Set 5 | temir
# Processing Record 22 of Set 5 | beyneu
# City not found. Skipping...
# Processing Record 23 of Set 5 | carupano
# Processing Record 24 of Set 5 | waipawa
# Processing Record 25 of Set 5 | shadrinsk
# Processing Record 26 of Set 5 | praia
# Processing Record 27 of Set 5 | paamiut
# Processing Record 28 of Set 5 | kilindoni
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | lasa
# City not found. Skipping...
# Processing Record 31 of Set 5 | port-cartier
# Processing Record 32 of Set 5 | mar del plata
# Processing Record 33 of Set 5 | touros
# City not found. Skipping...
# Processing Record 34 of Set 5 | kitsuki
# City not found. Skipping...
# Processing Record 35 of Set 5 | manasa
# Processing Record 36 of Set 5 | codrington
# Processing Record 37 of Set 5 | brae
# Processing Record 38 of Set 5 | cabinda
# City not found. Skipping...
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | farafangana
# Processing Record 41 of Set 5 | paternion
# Processing Record 42 of Set 5 | salalah
# Processing Record 43 of Set 5 | emerald
# Processing Record 44 of Set 5 | takoradi
# Processing Record 45 of Set 5 | bodaybo
# Processing Record 46 of Set 5 | san cristobal
# Processing Record 47 of Set 5 | padang
# Processing Record 48 of Set 5 | srednekolymsk
# Processing Record 49 of Set 5 | kodinar
# Processing Record 2 of Set 6 | chara
# Processing Record 3 of Set 6 | tecoanapa
# Processing Record 4 of Set 6 | aqtobe
# Processing Record 5 of Set 6 | kushmurun
# City not found. Skipping...
# Processing Record 6 of Set 6 | iqaluit
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | buala
# Processing Record 9 of Set 6 | rawah
# Processing Record 10 of Set 6 | peniche
# Processing Record 11 of Set 6 | nikolskoye
# Processing Record 12 of Set 6 | bulakamba
# Processing Record 13 of Set 6 | hobyo
# Processing Record 14 of Set 6 | kyabe
# City not found. Skipping...
# Processing Record 15 of Set 6 | kashiba
# Processing Record 16 of Set 6 | sisimiut
# Processing Record 17 of Set 6 | sandakan
# Processing Record 18 of Set 6 | port moresby
# Processing Record 19 of Set 6 | ashington
# Processing Record 20 of Set 6 | nabire
# Processing Record 21 of Set 6 | mareeba
# Processing Record 22 of Set 6 | rayachoti
# City not found. Skipping...
# Processing Record 23 of Set 6 | ouesso
# Processing Record 24 of Set 6 | kalmunai
# Processing Record 25 of Set 6 | tiznit
# Processing Record 26 of Set 6 | beidao
# Processing Record 27 of Set 6 | hilton head island
# Processing Record 28 of Set 6 | nuuk
# Processing Record 29 of Set 6 | iracoubo
# Processing Record 30 of Set 6 | cooma
# Processing Record 31 of Set 6 | ostrovnoy
# Processing Record 32 of Set 6 | iberia
# City not found. Skipping...
# Processing Record 33 of Set 6 | biltine
# Processing Record 34 of Set 6 | saint-joseph
# Processing Record 35 of Set 6 | lorengau
# Processing Record 36 of Set 6 | chuy
# Processing Record 37 of Set 6 | wakkanai
# Processing Record 38 of Set 6 | bongandanga
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | malanje
# Processing Record 41 of Set 6 | basoko
# Processing Record 42 of Set 6 | acton
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | saint-michel-des-saints
# Processing Record 45 of Set 6 | moron
# Processing Record 46 of Set 6 | dumai
# Processing Record 47 of Set 6 | elizabeth city
# Processing Record 48 of Set 6 | hithadhoo
# Processing Record 49 of Set 6 | shunyi
# Processing Record 2 of Set 7 | ramsar
# City not found. Skipping...
# Processing Record 3 of Set 7 | gua musang
# City not found. Skipping...
# Processing Record 4 of Set 7 | maldonado
# Processing Record 5 of Set 7 | saint-pierre
# Processing Record 6 of Set 7 | edgewater
# Processing Record 7 of Set 7 | imbituba
# Processing Record 8 of Set 7 | beloha
# Processing Record 9 of Set 7 | brigantine
# City not found. Skipping...
# Processing Record 10 of Set 7 | palmer
# Processing Record 11 of Set 7 | dong hoi
# City not found. Skipping...
# Processing Record 12 of Set 7 | jaen
# Processing Record 13 of Set 7 | bambous virieux
# Processing Record 14 of Set 7 | vilhena
# Processing Record 15 of Set 7 | cividale del friuli
# Processing Record 16 of Set 7 | ibra
# Processing Record 17 of Set 7 | saint-avold
# Processing Record 18 of Set 7 | kushima
# Processing Record 19 of Set 7 | cozumel
# City not found. Skipping...
# Processing Record 20 of Set 7 | totness
# Processing Record 21 of Set 7 | ayolas
# Processing Record 22 of Set 7 | livingston
# Processing Record 23 of Set 7 | ilulissat
# Processing Record 24 of Set 7 | panacan
# City not found. Skipping...
# Processing Record 25 of Set 7 | hanko
# City not found. Skipping...
# Processing Record 26 of Set 7 | nouakchott
# Processing Record 27 of Set 7 | sungairaya
# Processing Record 28 of Set 7 | sept-iles
# Processing Record 29 of Set 7 | rio grande
# Processing Record 30 of Set 7 | kolpashevo
# Processing Record 31 of Set 7 | half moon bay
# Processing Record 32 of Set 7 | santa cruz del sur
# Processing Record 33 of Set 7 | kristiansand
# Processing Record 34 of Set 7 | camacha
# Processing Record 35 of Set 7 | tiksi
# Processing Record 36 of Set 7 | beringovskiy
# Processing Record 37 of Set 7 | harper
# Processing Record 38 of Set 7 | jodar
# Processing Record 39 of Set 7 | nigde
# Processing Record 40 of Set 7 | rocha
# Processing Record 41 of Set 7 | sitka
# Processing Record 42 of Set 7 | aktau
# Processing Record 43 of Set 7 | kasongo-lunda
# Processing Record 44 of Set 7 | kaili
# Processing Record 45 of Set 7 | sorland
# Processing Record 46 of Set 7 | front royal
# Processing Record 47 of Set 7 | shilovo
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | luderitz
# Processing Record 2 of Set 8 | virginia beach
# Processing Record 3 of Set 8 | antalaha
# Processing Record 4 of Set 8 | pangody
# Processing Record 5 of Set 8 | mednogorsk
# Processing Record 6 of Set 8 | kaeo
# Processing Record 7 of Set 8 | maceio
# Processing Record 8 of Set 8 | rayong
# Processing Record 9 of Set 8 | windhoek
# Processing Record 10 of Set 8 | angoche
# Processing Record 11 of Set 8 | tikrit
# Processing Record 12 of Set 8 | del rio
# Processing Record 13 of Set 8 | lovozero
# Processing Record 14 of Set 8 | kassala
# Processing Record 15 of Set 8 | dongsheng
# City not found. Skipping...
# Processing Record 16 of Set 8 | sabang
# Processing Record 17 of Set 8 | saldanha
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | flinders
# City not found. Skipping...
# Processing Record 20 of Set 8 | kutum
# Processing Record 21 of Set 8 | santa marta
# Processing Record 22 of Set 8 | soldotna
# Processing Record 23 of Set 8 | iwaki
# Processing Record 24 of Set 8 | chumikan
# Processing Record 25 of Set 8 | svetlaya
# Processing Record 26 of Set 8 | sechura
# Processing Record 27 of Set 8 | kunya
# Processing Record 28 of Set 8 | kundiawa
# Processing Record 29 of Set 8 | weatherford
# Processing Record 30 of Set 8 | zhangye
# Processing Record 31 of Set 8 | bongor
# Processing Record 32 of Set 8 | izumo
# Processing Record 33 of Set 8 | businga
# Processing Record 34 of Set 8 | zwedru
# Processing Record 35 of Set 8 | sibu
# Processing Record 36 of Set 8 | kushiro
# City not found. Skipping...
# Processing Record 37 of Set 8 | skjervoy
# Processing Record 38 of Set 8 | algiers
# City not found. Skipping...
# Processing Record 39 of Set 8 | soyo
# Processing Record 40 of Set 8 | balkhash
# Processing Record 41 of Set 8 | grand gaube
# Processing Record 42 of Set 8 | chapayevka
# Processing Record 43 of Set 8 | mogadishu
# Processing Record 44 of Set 8 | uvalde
# Processing Record 45 of Set 8 | pucallpa
# Processing Record 46 of Set 8 | tarakan
# Processing Record 47 of Set 8 | skibbereen
# Processing Record 48 of Set 8 | whitehorse
# Processing Record 49 of Set 8 | kuching
# Processing Record 2 of Set 9 | doha
# Processing Record 3 of Set 9 | taoudenni
# Processing Record 4 of Set 9 | vanavara
# Processing Record 5 of Set 9 | micheweni
# City not found. Skipping...
# Processing Record 6 of Set 9 | juneau
# City not found. Skipping...
# Processing Record 7 of Set 9 | ostrov
# Processing Record 8 of Set 9 | pokaran
# Processing Record 9 of Set 9 | annau
# Processing Record 10 of Set 9 | knysna
# Processing Record 11 of Set 9 | las palmas
# City not found. Skipping...
# Processing Record 12 of Set 9 | rondonopolis
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | fuerte olimpo
# Processing Record 15 of Set 9 | cabedelo
# Processing Record 16 of Set 9 | nhulunbuy
# City not found. Skipping...
# Processing Record 17 of Set 9 | eirunepe
# City not found. Skipping...
# Processing Record 18 of Set 9 | naryan-mar
# Processing Record 19 of Set 9 | puerto del rosario
# Processing Record 20 of Set 9 | canmore
# Processing Record 21 of Set 9 | tingi
# Processing Record 22 of Set 9 | candolim
# Processing Record 23 of Set 9 | mayumba
# Processing Record 24 of Set 9 | xining
# City not found. Skipping...
# Processing Record 25 of Set 9 | batamshinskiy
# City not found. Skipping...
# Processing Record 26 of Set 9 | chichibu
# Processing Record 27 of Set 9 | ust-ilimsk
# Processing Record 28 of Set 9 | saurimo
# Processing Record 29 of Set 9 | darayya
# Processing Record 30 of Set 9 | giresun
# Processing Record 31 of Set 9 | bastia
# Processing Record 32 of Set 9 | sobolevo
# Processing Record 33 of Set 9 | rio cuarto
# Processing Record 34 of Set 9 | koungheul
# City not found. Skipping...
# Processing Record 35 of Set 9 | aswan
# Processing Record 36 of Set 9 | bilibino
# Processing Record 37 of Set 9 | burnie
# Processing Record 38 of Set 9 | mehamn
# Processing Record 39 of Set 9 | tshikapa
# Processing Record 40 of Set 9 | nizhneudinsk
# Processing Record 41 of Set 9 | noumea
# Processing Record 42 of Set 9 | kholtoson
# Processing Record 43 of Set 9 | padilla
# Processing Record 44 of Set 9 | novozavidovskiy
# Processing Record 45 of Set 9 | crab hill
# Processing Record 46 of Set 9 | khor
# Processing Record 47 of Set 9 | adrar
# Processing Record 48 of Set 9 | necochea
# Processing Record 49 of Set 9 | ribas do rio pardo
# Processing Record 2 of Set 10 | kahului
# Processing Record 3 of Set 10 | aasiaat
# City not found. Skipping...
# Processing Record 4 of Set 10 | corrales
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 10 | san juan de la maguana
# Processing Record 6 of Set 10 | lensk
# City not found. Skipping...
# Processing Record 7 of Set 10 | ahipara
# Processing Record 8 of Set 10 | tyazhinskiy
# Processing Record 9 of Set 10 | itacare
# Processing Record 10 of Set 10 | pemberton
# City not found. Skipping...
# Processing Record 11 of Set 10 | katangli
# Processing Record 12 of Set 10 | san policarpo
# Processing Record 13 of Set 10 | santarem
# Processing Record 14 of Set 10 | champerico
# Processing Record 15 of Set 10 | shitanjing
# Processing Record 16 of Set 10 | almaznyy
# Processing Record 17 of Set 10 | tres arroyos
# Processing Record 18 of Set 10 | ferme-neuve
# Processing Record 19 of Set 10 | faya
# Processing Record 20 of Set 10 | duki
# City not found. Skipping...
# Processing Record 21 of Set 10 | aragarcas
# Processing Record 22 of Set 10 | avera
# Processing Record 23 of Set 10 | peto
# Processing Record 24 of Set 10 | klaksvik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 10 | correntina
# Processing Record 26 of Set 10 | anaco
# Processing Record 27 of Set 10 | itabira
# Processing Record 28 of Set 10 | deputatskiy
# Processing Record 29 of Set 10 | mitu
# Processing Record 30 of Set 10 | pingliang
# Processing Record 31 of Set 10 | poum
# Processing Record 32 of Set 10 | baryatino
# Processing Record 33 of Set 10 | lima
# Processing Record 34 of Set 10 | kaniama
# Processing Record 35 of Set 10 | isangel
# Processing Record 36 of Set 10 | boa vista
# Processing Record 37 of Set 10 | sovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 10 | gunjur
# Processing Record 39 of Set 10 | cabo san lucas
# Processing Record 40 of Set 10 | tursunzoda
# Processing Record 41 of Set 10 | sioux lookout
# Processing Record 42 of Set 10 | siachoque
# City not found. Skipping...
# Processing Record 43 of Set 10 | storforshei
# Processing Record 44 of Set 10 | tucurui
# Processing Record 45 of Set 10 | cap malheureux
# Processing Record 46 of Set 10 | kviteseid
# Processing Record 47 of Set 10 | belmonte
# Processing Record 48 of Set 10 | vila
# Processing Record 49 of Set 10 | shirvan
# Processing Record 2 of Set 11 | agara
# Processing Record 3 of Set 11 | kochinda
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | bairiki
# Processing Record 7 of Set 11 | vallenar
# Processing Record 8 of Set 11 | nyurba
# Processing Record 9 of Set 11 | korem
# Processing Record 10 of Set 11 | zheleznodorozhnyy
# City not found. Skipping...
# Processing Record 11 of Set 11 | valparaiso
# Processing Record 12 of Set 11 | barabai
# City not found. Skipping...
# Processing Record 13 of Set 11 | chihuahua
# City not found. Skipping...
# Processing Record 14 of Set 11 | launceston
# Processing Record 15 of Set 11 | sorong
# Processing Record 16 of Set 11 | bhabua
# Processing Record 17 of Set 11 | thohoyandou
# Processing Record 18 of Set 11 | olafsvik
# Processing Record 19 of Set 11 | kanadey
# City not found. Skipping...
# Processing Record 20 of Set 11 | alofi
# Processing Record 21 of Set 11 | lucca
# Processing Record 22 of Set 11 | linares
# Processing Record 23 of Set 11 | skovorodino
# Processing Record 24 of Set 11 | petropolis
# Processing Record 25 of Set 11 | quiruvilca
# Processing Record 26 of Set 11 | pimentel
# Processing Record 27 of Set 11 | egvekinot
# Processing Record 28 of Set 11 | dawei
# Processing Record 29 of Set 11 | vestmannaeyjar
# Processing Record 30 of Set 11 | ajdabiya
# Processing Record 31 of Set 11 | namatanai
# Processing Record 32 of Set 11 | vieques
# Processing Record 33 of Set 11 | jalu
# City not found. Skipping...
# Processing Record 34 of Set 11 | liepaja
# Processing Record 35 of Set 11 | malinovskiy
# Processing Record 36 of Set 11 | murgab
# Processing Record 37 of Set 11 | kalamb
# Processing Record 38 of Set 11 | zhezkazgan
# Processing Record 39 of Set 11 | honningsvag
# Processing Record 40 of Set 11 | ratnagiri
# Processing Record 41 of Set 11 | maningrida
# Processing Record 42 of Set 11 | palatka
# Processing Record 43 of Set 11 | matagami
# Processing Record 44 of Set 11 | goderich
# City not found. Skipping...
# Processing Record 45 of Set 11 | coihaique
# Processing Record 46 of Set 11 | ouallam
# Processing Record 47 of Set 11 | awbari
# Processing Record 48 of Set 11 | hamilton
# Processing Record 49 of Set 11 | chapleau
# Processing Record 2 of Set 12 | milos
# Processing Record 3 of Set 12 | mokhsogollokh
# Processing Record 4 of Set 12 | meridian
# City not found. Skipping...
# Processing Record 5 of Set 12 | busayra
# Processing Record 6 of Set 12 | shizunai
# Processing Record 7 of Set 12 | kruisfontein
# Processing Record 8 of Set 12 | paka
# Processing Record 9 of Set 12 | merke
# Processing Record 10 of Set 12 | rehli
# Processing Record 11 of Set 12 | paciran
# Processing Record 12 of Set 12 | kalemie
# Processing Record 13 of Set 12 | durban
# ----------Data Retrieval Complete----------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# A weather dictionary of lists for dataframe:
weather_dictionary = {
    "City":city_names,
    "Country":countries,
    "Date":dates,
    "Lat.":latitudes,
    "Lon.":longitudes,
    "Max Temp.":max_temps,
    "Wind Speed":wind_speeds,
    "Cloudiness":cloudiness,
    "Humidity":humidities
}

# %%
# Convert data into dataframe:
weather_df = pd.DataFrame(weather_dictionary)
# Displaying top five rows of dataframe:
weather_df.head()
# Out:
#            City Country        Date     Lat.      Lon.  Max Temp.  Wind Speed  \
# 0     dhidhdhoo      MV  1615571910   6.8833   73.1000      83.43       13.51
# 1  norman wells      US  1615571691  35.2226  -97.4395      71.60       18.41
# 2       itarema      BR  1615571910  -2.9248  -39.9167      84.76       16.06
# 3         kapaa      US  1615571910  22.0752 -159.3190      73.00       12.66
# 4      sterling      US  1615571910  39.0062  -77.4286      62.01        8.05
#
#    Cloudiness  Humidity
# 0           3        75
# 1          90        73
# 2         100        68
# 3          90        88
# 4          90        72

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat."], weather_df["Max Temp."], edgecolors = "black", facecolors = "orange")
plt.title("A City's Latitudinal Location vs. Maximum Temperature (03/12/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(b=True, which="major", axis = "both", linestyle = '-', color = "lightgrey")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
